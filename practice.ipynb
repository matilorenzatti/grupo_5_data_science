# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import descartes 
import seaborn as sns
import plotly.express as px
import re

# %%
# Importanmos el archivo a usar
data = pd.read_csv("./properatti.csv")

df = data

# %%
df.head(5)
# Out:
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat  ...  surface_covered_in_m2  price_usd_per_m2 price_per_m2  \
# 0 -34.661824  ...                   40.0       1127.272727  1550.000000
# 1 -34.903883  ...                    NaN               NaN          NaN
# 2 -34.652262  ...                   55.0       1309.090909  1309.090909
# 3 -34.647797  ...                    NaN               NaN          NaN
# 4 -38.002626  ...                   35.0       1828.571429  1828.571429
#
#    floor  rooms  expenses                                      properati_url  \
# 0    NaN    NaN       NaN  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1    NaN    NaN       NaN  http://www.properati.com.ar/15bob_venta_depart...
# 2    NaN    NaN       NaN  http://www.properati.com.ar/15bod_venta_depart...
# 3    NaN    NaN       NaN  http://www.properati.com.ar/15boh_venta_ph_lin...
# 4    NaN    NaN       NaN  http://www.properati.com.ar/15bok_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...
#
# [5 rows x 26 columns]

# %%
print("--------------------------------")
print("Shape", df.shape)
print("--------------------------------")
print("Columnas y sus tipos", df.dtypes)
print("--------------------------------")
# Out:
# --------------------------------
# Shape (121220, 26)
# --------------------------------
# Columnas y sus tipos Unnamed: 0                      int64
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# image_thumbnail                object
# dtype: object
# --------------------------------

# %%
#Como vemos, da igual, por lo que pasamos a borrarla.
data = data.drop(["Unnamed: 0"], axis=1)
data.sample(2)
# Out:
#       operation property_type     place_name  \
# 23710      sell     apartment  Puerto Madero
# 64585      sell     apartment        Córdoba
#
#                          place_with_parent_names country_name  \
# 23710  |Argentina|Capital Federal|Puerto Madero|    Argentina
# 64585                        |Argentina|Córdoba|    Argentina
#
#             state_name  geonames_id                        lat-lon        lat  \
# 23710  Capital Federal    3429760.0  -34.6174015406,-58.3613479968 -34.617402
# 64585          Córdoba    3860255.0                            NaN        NaN
#
#              lon  ...  surface_covered_in_m2 price_usd_per_m2  price_per_m2  \
# 23710 -58.361348  ...                  125.0      5606.060606        5920.0
# 64585        NaN  ...                   70.0              NaN           NaN
#
#        floor  rooms  expenses  \
# 23710    NaN    3.0       NaN
# 64585    NaN    NaN       NaN
#
#                                            properati_url  \
# 23710  http://www.properati.com.ar/17mfi_venta_depart...
# 64585  http://www.properati.com.ar/1ab1q_venta_depart...
#
#                                              description  \
# 23710  Excelente departamento pasante en Zen City sec...
# 64585  Edificio CAÑITAS PARANA. Ubicado en la exclusi...
#
#                                   title  \
# 23710  Departamento en venta a estrenar
# 64585     Departamento en Nueva Cordoba
#
#                                          image_thumbnail
# 23710  https://thumbs4.properati.com/3/NTKgoA2cgcDcI4...
# 64585  https://thumbs4.properati.com/9/375YaSN6Vqf1IP...
#
# [2 rows x 25 columns]

# %%
#Borro la columna "operation" porque todas son ventas.
data = data.drop(["operation"], axis=1)
data.head(3)
# Out:
#   property_type place_name                      place_with_parent_names  \
# 0            PH  Mataderos        |Argentina|Capital Federal|Mataderos|
# 1     apartment   La Plata  |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|
# 2     apartment  Mataderos        |Argentina|Capital Federal|Mataderos|
#
#   country_name              state_name  geonames_id                  lat-lon  \
# 0    Argentina         Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1    Argentina  Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2    Argentina         Capital Federal    3430787.0  -34.6522615,-58.5229825
#
#          lat        lon     price  ... surface_covered_in_m2  \
# 0 -34.661824 -58.508839   62000.0  ...                  40.0
# 1 -34.903883 -57.964330  150000.0  ...                   NaN
# 2 -34.652262 -58.522982   72000.0  ...                  55.0
#
#    price_usd_per_m2  price_per_m2  floor  rooms  expenses  \
# 0       1127.272727   1550.000000    NaN    NaN       NaN
# 1               NaN           NaN    NaN    NaN       NaN
# 2       1309.090909   1309.090909    NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1  http://www.properati.com.ar/15bob_venta_depart...
# 2  http://www.properati.com.ar/15bod_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
#
# [3 rows x 24 columns]

# %%
# Drop column "lat-lon" porque es repetitiva
data = data.drop(["lat-lon"], axis=1)
data
# Out:
#        property_type       place_name  \
# 0                 PH        Mataderos
# 1          apartment         La Plata
# 2          apartment        Mataderos
# 3                 PH          Liniers
# 4          apartment           Centro
# ...              ...              ...
# 121215     apartment         Belgrano
# 121216         house           Beccar
# 121217     apartment    Villa Urquiza
# 121218     apartment      Plaza Colón
# 121219     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 3                     |Argentina|Capital Federal|Liniers|    Argentina
# 4       |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...                                                   ...          ...
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id        lat        lon  \
# 0                    Capital Federal    3430787.0 -34.661824 -58.508839
# 1             Bs.As. G.B.A. Zona Sur    3432039.0 -34.903883 -57.964330
# 2                    Capital Federal    3430787.0 -34.652262 -58.522982
# 3                    Capital Federal    3431333.0 -34.647797 -58.516424
# 4       Buenos Aires Costa Atlántica    3435548.0 -38.002626 -57.549447
# ...                              ...          ...        ...        ...
# 121215               Capital Federal    3436077.0        NaN        NaN
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0        NaN        NaN
# 121217               Capital Federal    3433775.0 -34.570639 -58.475596
# 121218  Buenos Aires Costa Atlántica          NaN        NaN        NaN
# 121219               Capital Federal    3433955.0        NaN        NaN
#
#            price currency  ...  surface_covered_in_m2  price_usd_per_m2  \
# 0        62000.0      USD  ...                   40.0       1127.272727
# 1       150000.0      USD  ...                    NaN               NaN
# 2        72000.0      USD  ...                   55.0       1309.090909
# 3        95000.0      USD  ...                    NaN               NaN
# 4        64000.0      USD  ...                   35.0       1828.571429
# ...          ...      ...  ...                    ...               ...
# 121215  870000.0      USD  ...                   93.0       7699.115044
# 121216  498000.0      USD  ...                  360.0       1383.333333
# 121217  131500.0      USD  ...                   39.0       2858.695652
# 121218   95900.0      USD  ...                   48.0       1997.916667
# 121219  129000.0      USD  ...                   77.0       1675.324675
#
#         price_per_m2  floor  rooms  expenses  \
# 0        1550.000000    NaN    NaN       NaN
# 1                NaN    NaN    NaN       NaN
# 2        1309.090909    NaN    NaN       NaN
# 3                NaN    NaN    NaN       NaN
# 4        1828.571429    NaN    NaN       NaN
# ...              ...    ...    ...       ...
# 121215   9354.838710    NaN    NaN   10000.0
# 121216   1383.333333    NaN    NaN       NaN
# 121217   3371.794872    NaN    NaN       NaN
# 121218   1997.916667    NaN    NaN       NaN
# 121219   1675.324675    NaN    NaN    3500.0
#
#                                             properati_url  \
# 0       http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1       http://www.properati.com.ar/15bob_venta_depart...
# 2       http://www.properati.com.ar/15bod_venta_depart...
# 3       http://www.properati.com.ar/15boh_venta_ph_lin...
# 4       http://www.properati.com.ar/15bok_venta_depart...
# ...                                                   ...
# 121215  http://www.properati.com.ar/1cja2_venta_depart...
# 121216  http://www.properati.com.ar/1cja6_venta_casa_b...
# 121217  http://www.properati.com.ar/1cja7_venta_depart...
# 121218  http://www.properati.com.ar/1cja8_venta_depart...
# 121219  http://www.properati.com.ar/1cjaa_venta_depart...
#
#                                               description  \
# 0       2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1       Venta de departamento en décimo piso al frente...
# 2       2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3       PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4       DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# ...                                                   ...
# 121215  TORRE FORUM ALCORTA - MÁXIMA CATEGORÍA.Impecab...
# 121216  Excelente e impecable casa en Venta en Las Lom...
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218  2 Amb al contrafrente,  luminoso. El departame...
# 121219  Departamento de 77 m2 apto profesional. Edific...
#
#                                                     title  \
# 0                      2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1       VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2                2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                            PH 3 amb. cfte. reciclado
# 4       DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# ...                                                   ...
# 121215         Torre Forum Alcorta- Impecable 3 ambientes
# 121216  Ruca Inmuebles | Venta | Lomas de San Isidro |...
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218  2 amb. C/ dep. de servicio al contrafrente| Re...
# 121219         Departamento apto profesional en el Centro
#
#                                           image_thumbnail
# 0       https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1       https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
# 2       https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
# 3       https://thumbs4.properati.com/3/DgIfX-85Mog5SP...
# 4       https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...
# ...                                                   ...
# 121215  https://thumbs4.properati.com/1/bjms0KnaAnlNoQ...
# 121216  https://thumbs4.properati.com/2/PCc3WuQDjpNZc4...
# 121217  https://thumbs4.properati.com/9/YAe_-2gRVykADP...
# 121218  https://thumbs4.properati.com/8/Q12PTvU6BQJ0ib...
# 121219  https://thumbs4.properati.com/8/mNEsnQWqB7joBF...
#
# [121220 rows x 23 columns]

# %%
# Deseamos conocer el porcentaje de nulos por columna;
porcentaje_nulos_por_columna= (pd.isna(df).sum()/len(df))*100
round(porcentaje_nulos_por_columna.sort_values(ascending=False),2)
# Out:
# floor                         93.48
# expenses                      88.23
# rooms                         60.91
# price_usd_per_m2              43.39
# lon                           42.53
# lat-lon                       42.53
# lat                           42.53
# surface_total_in_m2           32.44
# price_per_m2                  27.69
# currency                      16.84
# price_aprox_usd               16.84
# price_aprox_local_currency    16.84
# price                         16.84
# surface_covered_in_m2         16.42
# geonames_id                   15.44
# image_thumbnail                2.57
# place_name                     0.02
# description                    0.00
# title                          0.00
# properati_url                  0.00
# state_name                     0.00
# country_name                   0.00
# place_with_parent_names        0.00
# property_type                  0.00
# operation                      0.00
# Unnamed: 0                     0.00
# dtype: float64

# %%
# Revisamos el porcentaje de propiedades que hay en cada región.
state_name_mix = (data["state_name"].value_counts()/len(data)).reset_index()
state_name_mix['state_name'] = (state_name_mix['state_name']*100).round(1) 
state_name_mix.columns = ['state_name', 'mix']
state_name_mix
# Out:
#                       state_name   mix
# 0                Capital Federal  26.7
# 1       Bs.As. G.B.A. Zona Norte  21.1
# 2         Bs.As. G.B.A. Zona Sur  11.5
# 3                        Córdoba  10.0
# 4                       Santa Fe   8.4
# 5   Buenos Aires Costa Atlántica   8.3
# 6       Bs.As. G.B.A. Zona Oeste   7.7
# 7          Buenos Aires Interior   1.9
# 8                      Río Negro   0.7
# 9                        Neuquén   0.6
# 10                       Mendoza   0.6
# 11                       Tucumán   0.6
# 12                    Corrientes   0.5
# 13                      Misiones   0.4
# 14                    Entre Ríos   0.3
# 15                         Salta   0.2
# 16                        Chubut   0.2
# 17                      San Luis   0.2
# 18                      La Pampa   0.1
# 19                       Formosa   0.1
# 20                         Chaco   0.0
# 21                      San Juan   0.0
# 22              Tierra Del Fuego   0.0
# 23                     Catamarca   0.0
# 24                         Jujuy   0.0
# 25                    Santa Cruz   0.0
# 26                      La Rioja   0.0
# 27           Santiago Del Estero   0.0

# %%
#Calculamos la cantidad de datos que van a quedar fuera en el nuevo df por tener pocos datos.
state_name_mix_menor_1_9 = state_name_mix[state_name_mix["mix"]<1.9]["state_name"].tolist()

data.loc[data["state_name"].isin(state_name_mix_menor_1_9),:].shape
# Out:
# (5532, 23)

# %%
#Sort dataframe by columns

data_column_sorted = {
    "floor": data["floor"],
    "expenses": data["expenses"],
    "rooms": data["rooms"],
    "price_usd_per_m2": data["price_usd_per_m2"],
    "lon": data["lon"],
    "lat": data["lat"],
    "surface_total_in_m2": data["surface_total_in_m2"],
    "currency": data["currency"],
    "price_aprox_usd": data["price_aprox_usd"],
    "price_aprox_local_currency": data["price_aprox_local_currency"],
    "price": data["price"],
    "surface_covered_in_m2": data["surface_covered_in_m2"],
    "place_name": data["place_name"],
    "geonames_id": data["geonames_id"],
    "state_name": data["state_name"],
    "title": data["title"],
    "description": data["description"],
    "property_type": data["property_type"]
}

data2 = pd.DataFrame(data_column_sorted)

# %%
data2 = data2.set_index("state_name")

# %%
#Antes de hacer el count de abajo, quiero, en esta línea, dejar sólo los registros iguales a:
state_name_list_ok = ["Capital Federal",
"Bs.As. G.B.A. Zona Norte",
"Bs.As. G.B.A. Zona Sur",
"Córdoba",
"Santa Fe",
"Buenos Aires Costa Atlántica",
"Bs.As. G.B.A. Zona Oeste",
"Buenos Aires Interior"]

# %%
data2.shape
# Out:
# (121220, 17)

# %%
data2.loc[state_name_list_ok, :].shape
# Out:
# (115688, 17)

# %%
# df con los datos de los 8 state_name más importantes.
data2 = data2.loc[state_name_list_ok, :]

# %%
# Vemos los valores de mean y max de apartment porque nos habíamos encontrado con números de 2mil para arriba;
data2.groupby(["state_name", "property_type"]).describe().loc["Capital Federal"]
# Out:
#                 floor                                                      \
#                 count       mean        std  min  25%  50%    75%     max
# property_type
# PH              155.0   2.251613   2.211521  1.0  1.0  1.0   3.00    16.0
# apartment      2838.0  13.243834  84.696737  1.0  2.0  4.0   7.00  2509.0
# house             8.0  10.875000   7.395703  2.0  6.0  9.5  14.00    26.0
# store             8.0   9.375000  10.979689  1.0  2.0  3.0  15.25    31.0
#
#               expenses               ... surface_covered_in_m2            \
#                  count         mean  ...                   75%       max
# property_type                        ...
# PH               182.0   962.730769  ...                 115.0    1183.0
# apartment       6196.0  6634.878631  ...                  79.0  187000.0
# house             12.0  2675.916667  ...                 320.0    8175.0
# store            202.0  2896.549505  ...                 231.0   10958.0
#
#               geonames_id                                                     \
#                     count          mean            std        min        25%
# property_type
# PH                 1766.0  3.529494e+06  556658.475395  3427366.0  3429422.0
# apartment         25950.0  3.530139e+06  555737.593268  3427366.0  3429760.0
# house              2021.0  3.469355e+06  345993.449956  3427366.0  3430114.0
# store              1293.0  3.578327e+06  675300.520405  3427366.0  3429595.0
#
#
#                      50%        75%        max
# property_type
# PH             3430787.0  3433955.0  6693230.0
# apartment      3433775.0  3436003.0  6693230.0
# house          3433910.0  3433955.0  6693230.0
# store          3430787.0  3435548.0  6693230.0
#
# [4 rows x 96 columns]

# %%
#Vemos la cantidad de no nulos en la columna floor para todos los datos.
data2.loc[data2["floor"].notnull()].describe()
# Out:
#              floor      expenses        rooms  price_usd_per_m2          lon  \
# count  7615.000000   1027.000000  5441.000000       3208.000000  5905.000000
# mean     17.403152   2522.842259     2.647307       2340.929008   -59.683618
# std     116.985284   2481.155954     1.271013        868.641196     2.270634
# min       1.000000      1.000000     1.000000         29.906933   -75.678931
# 25%       1.000000   1200.000000     2.000000       1857.142857   -60.639286
# 50%       3.000000   1800.000000     3.000000       2239.436620   -58.478612
# 75%       6.000000   2869.000000     3.000000       2787.656423   -58.423104
# max    2509.000000  19000.000000    22.000000      19800.000000   -56.674305
#
#                lat  surface_total_in_m2  price_aprox_usd  \
# count  5905.000000          3595.000000     6.795000e+03
# mean    -33.928174            81.444228     2.251617e+05
# std       1.488243           245.697695     3.037610e+05
# min     -38.583214            10.000000     0.000000e+00
# 25%     -34.618785            45.000000     9.200000e+04
# 50%     -34.589013            60.000000     1.380000e+05
# 75%     -32.957491            84.000000     2.250000e+05
# max       4.545843          9563.000000     3.900000e+06
#
#        price_aprox_local_currency         price  surface_covered_in_m2  \
# count                6.795000e+03  6.795000e+03            6898.000000
# mean                 3.972866e+06  3.527507e+05              99.895332
# std                  5.359711e+06  6.354222e+05             325.831184
# min                  0.000000e+00  0.000000e+00               1.000000
# 25%                  1.623294e+06  1.020000e+05              44.000000
# 50%                  2.434941e+06  1.500000e+05              60.000000
# 75%                  3.970012e+06  2.710000e+05              93.000000
# max                  6.881355e+07  1.168104e+07           12731.000000
#
#         geonames_id
# count  6.812000e+03
# mean   3.635403e+06
# std    5.406267e+05
# min    3.427326e+06
# 25%    3.429651e+06
# 50%    3.433955e+06
# 75%    3.838574e+06
# max    6.942539e+06

# %%
data2["floor"].sort_values(ascending=False).head(40)
# Out:
# state_name
# Capital Federal             2509.0
# Bs.As. G.B.A. Zona Norte    2177.0
# Capital Federal             2103.0
# Bs.As. G.B.A. Zona Norte    1609.0
# Bs.As. G.B.A. Zona Norte    1609.0
# Bs.As. G.B.A. Zona Norte    1609.0
# Bs.As. G.B.A. Zona Norte    1609.0
# Bs.As. G.B.A. Zona Norte    1608.0
# Bs.As. G.B.A. Zona Norte    1608.0
# Bs.As. G.B.A. Zona Norte    1607.0
# Bs.As. G.B.A. Zona Norte    1606.0
# Bs.As. G.B.A. Zona Norte    1602.0
# Bs.As. G.B.A. Zona Norte    1512.0
# Bs.As. G.B.A. Zona Norte    1504.0
# Bs.As. G.B.A. Zona Norte    1504.0
# Bs.As. G.B.A. Zona Norte    1450.0
# Bs.As. G.B.A. Zona Norte    1420.0
# Bs.As. G.B.A. Zona Norte    1407.0
# Bs.As. G.B.A. Zona Norte    1404.0
# Bs.As. G.B.A. Zona Norte    1403.0
# Bs.As. G.B.A. Zona Norte    1401.0
# Bs.As. G.B.A. Zona Norte    1379.0
# Bs.As. G.B.A. Zona Norte    1306.0
# Bs.As. G.B.A. Zona Norte    1305.0
# Bs.As. G.B.A. Zona Norte    1304.0
# Bs.As. G.B.A. Zona Norte    1301.0
# Bs.As. G.B.A. Zona Norte    1291.0
# Bs.As. G.B.A. Zona Norte    1208.0
# Bs.As. G.B.A. Zona Norte    1206.0
# Bs.As. G.B.A. Zona Norte    1204.0
# Bs.As. G.B.A. Zona Norte    1202.0
# Bs.As. G.B.A. Zona Norte    1201.0
# Bs.As. G.B.A. Zona Norte    1109.0
# Bs.As. G.B.A. Zona Norte    1106.0
# Capital Federal             1104.0
# Bs.As. G.B.A. Zona Norte    1104.0
# Capital Federal             1001.0
# Bs.As. G.B.A. Zona Norte     910.0
# Bs.As. G.B.A. Zona Norte     908.0
# Bs.As. G.B.A. Zona Norte     908.0
# Name: floor, dtype: float64

# %%
#Cantidad de datos no nulos en floor.
data2["floor"].count()
# Out:
# 7615

# %%
# Buscamos el dato del edificio más grande de arg que tiene 54 pisos.
data2["floor"][data2["floor"] > 54].count()
# Out:
# 180

# %%
data2.reset_index(inplace=True)

# %%
# Rescatamos el index de todos los que son mayores a 54.
indices_mayor_54_floor = data2[data2["floor"] > 54].index

# %%
indices_mayor_54_floor = indices_mayor_54_floor.tolist()

# %%
# porcentaje de los valores outliers de floor mayores a 54.as_integer_ratio

180/7615*100
# Out:
# 2.3637557452396587

# %%
# La cantidad de datos erróneos en la columna floor respecto a la cantidad total de datos.
180/data.shape[0]*100
# Out:
# 0.14849034812737172

# %%
# Imputamos los datos mayores a 54 de la columna floor por apartment con NAN.
data2["floor"].where(data2["floor"] < 54, np.NAN, inplace=True)

# %%
# Verificamos que los 180 datos que tenían datos erróneos en la columna floor, fueron reemplazados por NAN.
data2[data2.index.isin(indices_mayor_54_floor)].head(3)
# Out:
#            state_name  floor  expenses  rooms  price_usd_per_m2        lon  \
# 984   Capital Federal    NaN       NaN    2.0               NaN -58.479707
# 1269  Capital Federal    NaN       NaN    3.0               NaN -58.472350
# 1270  Capital Federal    NaN       NaN    4.0               NaN -58.472617
#
#             lat  surface_total_in_m2 currency  price_aprox_usd  \
# 984  -34.566330                  NaN      USD         175000.0
# 1269 -34.575419                  NaN      NaN              NaN
# 1270 -34.575560                  NaN      NaN              NaN
#
#       price_aprox_local_currency     price  surface_covered_in_m2  \
# 984                    3087787.5  175000.0                   65.0
# 1269                         NaN       NaN                    NaN
# 1270                         NaN       NaN                    NaN
#
#          place_name  geonames_id  \
# 984   Villa Urquiza    3433775.0
# 1269       Belgrano    3436077.0
# 1270       Belgrano    3436077.0
#
#                                                   title  \
# 984   2 AMB BALCÓN CON PARRILLA - EDIFICIO CON AMENI...
# 1269    LA PAMPA AL 4300, Exclusivo Desarrollo en Pesos
# 1270              LA PAMPA 4300 AIR PAMPA POZO EN PESOS
#
#                                             description property_type
# 984   Corredor Responsable: Rebeca Stern - C.U.C.I.C...     apartment
# 1269  Corredor Responsable: Raul Hector Merlo - CUCI...     apartment
# 1270  Corredor Responsable: Raul Hector Merlo - CUCI...     apartment

# %%
# Pensamos en imputar los datos que son casas con valores de 0, porque tienen piso cero, de ahí empezamos a hacer el siguiente análisis:

# Contamos la cantidad de registros que son casas.
data2_house = data2.loc[data2["property_type"] == "house"]
# print("Cantidad de registros que son casas del df: ", data2_house, sep="")

pd.DataFrame(data2_house)
# Out:
#                    state_name  floor  expenses  rooms  price_usd_per_m2  \
# 13            Capital Federal    NaN       NaN    NaN        875.000000
# 15            Capital Federal    NaN       NaN    NaN       1091.269841
# 26            Capital Federal    NaN       NaN    NaN        944.444444
# 27            Capital Federal    NaN       NaN    NaN        658.602151
# 28            Capital Federal    NaN       NaN    NaN        611.111111
# ...                       ...    ...       ...    ...               ...
# 115678  Buenos Aires Interior    NaN       NaN    5.0        400.801603
# 115680  Buenos Aires Interior    NaN       NaN    4.0        747.782267
# 115684  Buenos Aires Interior    NaN       NaN    5.0        172.839506
# 115686  Buenos Aires Interior    NaN       NaN    4.0        192.307692
# 115687  Buenos Aires Interior    NaN       NaN    NaN               NaN
#
#               lon        lat  surface_total_in_m2 currency  price_aprox_usd  \
# 13     -58.362056 -34.617719                 80.0      USD         70000.00
# 15     -58.410702 -34.636321                504.0      USD        550000.00
# 26            NaN        NaN                180.0      USD        170000.00
# 27            NaN        NaN                744.0      USD        490000.00
# 28            NaN        NaN                720.0      USD        440000.00
# ...           ...        ...                  ...      ...              ...
# 115678 -59.100573 -37.313734                499.0      USD        200000.00
# 115680 -62.277651 -38.730753                 75.0      ARS         56083.67
# 115684        NaN        NaN               1215.0      USD        210000.00
# 115686 -58.259803 -37.837561                390.0      USD         75000.00
# 115687        NaN        NaN                  NaN      USD        130000.00
#
#         price_aprox_local_currency      price  surface_covered_in_m2  \
# 13                      1235115.00    70000.0                   50.0
# 15                      9704475.00   550000.0                  324.0
# 26                      2999565.00   170000.0                  165.0
# 27                      8645805.00   490000.0                  350.0
# 28                      7763580.00   440000.0                  261.0
# ...                            ...        ...                    ...
# 115678                  3528900.00   200000.0                  156.0
# 115680                   989568.31  1000000.0                   70.0
# 115684                  3705345.00   210000.0                  250.0
# 115686                  1323337.50    75000.0                  135.0
# 115687                  2293785.00   130000.0                  105.0
#
#                   place_name  geonames_id  \
# 13             Puerto Madero    3429760.0
# 15                     Boedo    3436003.0
# 26           Capital Federal    3433955.0
# 27           Capital Federal    3433955.0
# 28           Capital Federal    3433955.0
# ...                      ...          ...
# 115678                Tandil    3427832.0
# 115680          Bahía Blanca    3865084.0
# 115684  Sierra de los Padres    3427958.0
# 115686              Balcarce    3436176.0
# 115687                 Luján    3430982.0
#
#                                                     title  \
# 13      FLOAT LIFE - CASA FLOTANTE - UBICABLE EN CLUBS...
# 15              Casa impecable refaccionada! 6 ambientes.
# 26      Casa 180m² con 2 Plantas en Navarro, Julián 29...
# 27      Casa 744m² con 2 Plantas en Del Valle Iberluce...
# 28      Casa 720m² con Plantas en Palma, Diego 1800, A...
# ...                                                   ...
# 115678                                         Casa venta
# 115680                            Oportunidad Donado 1100
# 115684                              Sierras de los Padres
# 115686                           Casa+ Depto monoambiente
# 115687                                Casa - Hosteria Sur
#
#                                               description property_type
# 13      ESTRUCTURA ECOLOGICA FLOTANTEIDEAL PARA UBICAR...         house
# 15      Se encuentra dentro del Distrito Tecnológico. ...         house
# 26      Casa en 2 Plantas en BÂ° La Merced, a Metros d...         house
# 27      Lote: 744,76 m. (Frente: 17,32 x 43 de fondo) ...         house
# 28      PB. Liv y com con chimenea con salida a jardin...         house
# ...                                                   ...           ...
# 115678  Casa con 4 dormitorios. Living, Cocina, Comedo...         house
# 115680  Casa al frente en PH compuesta de 2 dormitorio...         house
# 115684  Chalet 5 Ambientes sobre 2 lotes de 600mts c/u...         house
# 115686  Lote de 13x30, 2 habitaciones, living comedor ...         house
# 115687  Casa quinta compuesta de 2 dormitorios, baño, ...         house
#
# [37554 rows x 18 columns]

# %%
#Obtenemos el index de todos los datos que son casas:
indices_floor_house = data2.loc[data2["property_type"] == "house"].index.tolist()
# print("Indices de los registros que son casas: ", indices_floor_house)
len(indices_floor_house)
# Out:
# 37554

# %%
# ¿Qué porcentaje representan las casas del total de registros?
print("Porcentaje de registros que son casas del df: ", data2_house.shape[0] / data2.shape[0] * 100," %", sep="")
# Out:
# Porcentaje de registros que son casas del df: 32.46144803263951 %

# %%
# Imputamos todos los registros de casas para que tengan en floor, valor 0 (cero)
data2.loc[data2["property_type"]=="house","floor"] = 0

# %%
# Verificamos que haya cambiado todos los valores a cero del paso anterior.
data2[["property_type", "floor"]].head(50)
# Out:
#    property_type  floor
# 0             PH    NaN
# 1      apartment    NaN
# 2             PH    NaN
# 3      apartment    NaN
# 4      apartment    NaN
# 5      apartment    NaN
# 6      apartment    NaN
# 7             PH    NaN
# 8      apartment    NaN
# 9      apartment    NaN
# 10     apartment    NaN
# 11     apartment    NaN
# 12     apartment    NaN
# 13         house    0.0
# 14     apartment    NaN
# 15         house    0.0
# 16     apartment    NaN
# 17     apartment    NaN
# 18     apartment    NaN
# 19     apartment    NaN
# 20         store    NaN
# 21     apartment    NaN
# 22     apartment    NaN
# 23     apartment    NaN
# 24     apartment    NaN
# 25     apartment    NaN
# 26         house    0.0
# 27         house    0.0
# 28         house    0.0
# 29         house    0.0
# 30     apartment   12.0
# 31         house    0.0
# 32            PH    1.0
# 33         house    0.0
# 34     apartment    NaN
# 35     apartment    6.0
# 36     apartment    NaN
# 37     apartment    NaN
# 38            PH    NaN
# 39     apartment    NaN
# 40            PH    NaN
# 41         store    NaN
# 42     apartment    NaN
# 43     apartment    NaN
# 44     apartment    NaN
# 45     apartment    NaN
# 46     apartment    NaN
# 47         store    NaN
# 48     apartment    NaN
# 49     apartment    NaN

# %%
# Verificamos que todos los registros con "property_type" == "house", ahora tengan "floor" == 0
data2[data2.index.isin(indices_floor_house)].head(3)
# Out:
#          state_name  floor  expenses  rooms  price_usd_per_m2        lon  \
# 13  Capital Federal    0.0       NaN    NaN        875.000000 -58.362056
# 15  Capital Federal    0.0       NaN    NaN       1091.269841 -58.410702
# 26  Capital Federal    0.0       NaN    NaN        944.444444        NaN
#
#           lat  surface_total_in_m2 currency  price_aprox_usd  \
# 13 -34.617719                 80.0      USD          70000.0
# 15 -34.636321                504.0      USD         550000.0
# 26        NaN                180.0      USD         170000.0
#
#     price_aprox_local_currency     price  surface_covered_in_m2  \
# 13                   1235115.0   70000.0                   50.0
# 15                   9704475.0  550000.0                  324.0
# 26                   2999565.0  170000.0                  165.0
#
#          place_name  geonames_id  \
# 13    Puerto Madero    3429760.0
# 15            Boedo    3436003.0
# 26  Capital Federal    3433955.0
#
#                                                 title  \
# 13  FLOAT LIFE - CASA FLOTANTE - UBICABLE EN CLUBS...
# 15          Casa impecable refaccionada! 6 ambientes.
# 26  Casa 180m² con 2 Plantas en Navarro, Julián 29...
#
#                                           description property_type
# 13  ESTRUCTURA ECOLOGICA FLOTANTEIDEAL PARA UBICAR...         house
# 15  Se encuentra dentro del Distrito Tecnológico. ...         house
# 26  Casa en 2 Plantas en BÂ° La Merced, a Metros d...         house

# %%
# Vemos que luego de la imputación, bajó considerablemente la cantidad de nulos de la columna floor.
data2.isnull().sum()
# Out:
# state_name                         0
# floor                          71426
# expenses                      101758
# rooms                          69989
# price_usd_per_m2               49058
# lon                            48639
# lat                            48639
# surface_total_in_m2            37058
# currency                       17871
# price_aprox_usd                17870
# price_aprox_local_currency     17870
# price                          17870
# surface_covered_in_m2          17744
# place_name                        23
# geonames_id                    18527
# title                              0
# description                        2
# property_type                      0
# dtype: int64

# %%
# Deseamos conocer el porcentaje de nulos por columna, vemos que el porcentaje de floor bajó considerablemente;
porcentaje_nulos_por_columna= (pd.isna(data2).sum()/len(data2))*100
round(porcentaje_nulos_por_columna.sort_values(ascending=False),2)
# Out:
# expenses                      87.96
# floor                         61.74
# rooms                         60.50
# price_usd_per_m2              42.41
# lat                           42.04
# lon                           42.04
# surface_total_in_m2           32.03
# geonames_id                   16.01
# currency                      15.45
# price                         15.45
# price_aprox_local_currency    15.45
# price_aprox_usd               15.45
# surface_covered_in_m2         15.34
# place_name                     0.02
# description                    0.00
# property_type                  0.00
# title                          0.00
# state_name                     0.00
# dtype: float64

# %%
# Analizamos cómo cambió la media, el std, y el max de floor luego de los cambios.
data2.loc[(data2["property_type"] == "apartment") & (data2["state_name"] == "Capital Federal"), :].describe()
# Out:
#              floor      expenses         rooms  price_usd_per_m2  \
# count  2773.000000  6.196000e+03  13482.000000      19896.000000
# mean      4.955283  6.634879e+03      2.545097       3324.464870
# std       4.337346  1.796656e+05      1.439610       3892.824716
# min       1.000000  1.000000e+00      1.000000         31.369688
# 25%       2.000000  1.200000e+03      1.000000       2111.111111
# 50%       4.000000  2.000000e+03      2.000000       2566.046646
# 75%       7.000000  3.900000e+03      3.000000       3168.758621
# max      43.000000  1.000150e+07     22.000000     206333.333333
#
#                 lon           lat  surface_total_in_m2  price_aprox_usd  \
# count  19446.000000  19446.000000         22580.000000     2.415400e+04
# mean     -58.433276    -34.599753            87.589017     2.453469e+05
# std        0.053687      0.037507          1332.550832     4.397744e+05
# min      -63.616672    -38.416097             0.000000     5.103610e+03
# 25%      -58.461123    -34.619692            40.000000     9.901250e+04
# 50%      -58.434144    -34.600369            56.000000     1.450000e+05
# 75%      -58.402259    -34.580400            89.000000     2.500000e+05
# max      -58.354956    -34.534530        200000.000000     4.654544e+07
#
#        price_aprox_local_currency         price  surface_covered_in_m2  \
# count                2.415400e+04  2.415400e+04           25240.000000
# mean                 4.329024e+06  3.706782e+05              79.353843
# std                  7.759600e+06  1.042946e+06            1183.327820
# min                  9.005064e+04  5.500000e+03               0.000000
# 25%                  1.747026e+06  1.040905e+05              37.000000
# 50%                  2.558452e+06  1.540000e+05              50.000000
# 75%                  4.411125e+06  2.890000e+05              79.000000
# max                  8.212711e+08  5.000000e+07          187000.000000
#
#         geonames_id
# count  2.595000e+04
# mean   3.530139e+06
# std    5.557376e+05
# min    3.427366e+06
# 25%    3.429760e+06
# 50%    3.433775e+06
# 75%    3.436003e+06
# max    6.693230e+06

# %%
# Total de datos diferentes a NaN y diferentes a cero, filtrados por departamentos.
dptos_dif_nan_y_cero = data2.loc[(data2["floor"] != 0) & (~np.isnan(data2["floor"]))& (data2["property_type"] == "apartment"), :].shape

print("(dptos) Total de datos diferentes a NaN y diferentes a cero: ", dptos_dif_nan_y_cero)
# Out:
# (dptos) Total de datos diferentes a NaN y diferentes a cero:  (6158, 18)

# %%
# Cantidad total de registros de dptos en el dataset.
dptos_all_shape = data2.loc[data2["property_type"] == "apartment"].shape
print("Cantidad total de registros de dptos en el dataset: ", dptos_all_shape)
# Out:
# Cantidad total de registros de dptos en el dataset:  (68740, 18)

# %%
# Porcentaje de registros de dptos en todo el dataset con valores distintos de cero y distintos de NaN, respecto al total de registros de dptos.
proporcion_dptos_not_nan_ni_cero_all_dptos = dptos_dif_nan_y_cero[0] / dptos_all_shape[0] * 100

print("Relación dptos not null ni cero respecto a total dptos: ", proporcion_dptos_not_nan_ni_cero_all_dptos)
# Out:
# Relación dptos not null ni cero respecto a total dptos:  8.958393948210649

# %% [markdown]
# Decición final sobre la columna "floor": Bye.
#
# Motivo: La proporción de departamentos que no tienen valores cero ni NaN, respecto del total es demasiado baja para tomar decisiones al respecto.

# %%
# drop columna floor respecto a la conclusión de arriba;

# %%
data2.groupby("state_name").sum()
# Out:
#                                 floor    expenses    rooms  price_usd_per_m2  \
# state_name
# Bs.As. G.B.A. Zona Norte       7147.0  12926104.0  21661.0      3.238687e+07
# Bs.As. G.B.A. Zona Oeste       2057.0   1756889.0  14329.0      6.240610e+06
# Bs.As. G.B.A. Zona Sur         1118.0   4287371.0   9420.0      9.416028e+06
# Buenos Aires Costa Atlántica    825.0    906538.0  22004.0      9.998920e+06
# Buenos Aires Interior            84.0    183488.0   3798.0      9.705104e+05
# Capital Federal               14165.0  41902139.0  41584.0      7.304215e+07
# Córdoba                        1950.0   3829720.0  16755.0      4.480915e+06
# Santa Fe                       2238.0   1930574.0  10017.0      8.625408e+06
#
#                                        lon            lat  \
# state_name
# Bs.As. G.B.A. Zona Norte     -6.709070e+05 -394168.331187
# Bs.As. G.B.A. Zona Oeste     -3.293698e+05 -194598.172284
# Bs.As. G.B.A. Zona Sur       -3.478982e+05 -207740.771305
# Buenos Aires Costa Atlántica -4.714543e+05 -310316.140925
# Buenos Aires Interior        -9.348831e+04  -57073.157595
# Capital Federal              -1.389029e+06 -822485.221406
# Córdoba                      -3.291815e+05 -161139.841850
# Santa Fe                     -3.266505e+05 -175822.377721
#
#                               surface_total_in_m2  price_aprox_usd  \
# state_name
# Bs.As. G.B.A. Zona Norte                5888821.0     7.802421e+09
# Bs.As. G.B.A. Zona Oeste                1593780.0     1.228612e+09
# Bs.As. G.B.A. Zona Sur                  1639034.0     2.399546e+09
# Buenos Aires Costa Atlántica            1492864.0     1.299341e+09
# Buenos Aires Interior                   1269373.0     3.324155e+08
# Capital Federal                         3151884.0     7.823345e+09
# Córdoba                                 2050506.0     1.840356e+09
# Santa Fe                                 997608.0     7.557069e+08
#
#                               price_aprox_local_currency         price  \
# state_name
# Bs.As. G.B.A. Zona Norte                    1.376698e+11  1.101509e+10
# Bs.As. G.B.A. Zona Oeste                    2.167825e+10  1.410931e+09
# Bs.As. G.B.A. Zona Sur                      4.233879e+10  2.932530e+09
# Buenos Aires Costa Atlántica                2.292623e+10  2.154183e+09
# Buenos Aires Interior                       5.865305e+09  6.040101e+08
# Capital Federal                             1.380390e+11  1.111251e+10
# Córdoba                                     3.247216e+10  8.484470e+09
# Santa Fe                                    1.333407e+10  6.211581e+09
#
#                               surface_covered_in_m2   geonames_id
# state_name
# Bs.As. G.B.A. Zona Norte                  4279033.0  5.289845e+10
# Bs.As. G.B.A. Zona Oeste                  1030931.0  2.742407e+10
# Bs.As. G.B.A. Zona Sur                    1634320.0  3.267782e+10
# Buenos Aires Costa Atlántica               888034.0  3.088088e+10
# Buenos Aires Interior                      290854.0  7.794471e+09
# Capital Federal                           2931325.0  1.094785e+11
# Córdoba                                   1283796.0  4.633996e+10
# Santa Fe                                   592367.0  3.897947e+10

# %%
data2.groupby(["state_name","property_type"]).describe()
# Out:
#                                               floor                        \
#                                               count       mean        std
# state_name                   property_type
# Bs.As. G.B.A. Zona Norte     PH                14.0   1.714286   1.138729
#                              apartment       1623.0   4.380160   5.102793
#                              house          13364.0   0.000000   0.000000
#                              store             13.0   1.076923   0.277350
# Bs.As. G.B.A. Zona Oeste     PH                31.0   3.000000   2.280351
#                              apartment        535.0   3.661682   2.856678
#                              house           4663.0   0.000000   0.000000
#                              store              4.0   1.250000   0.500000
# Bs.As. G.B.A. Zona Sur       PH                24.0   2.166667   2.035910
#                              apartment        237.0   4.485232   3.496486
#                              house           6985.0   0.000000   0.000000
#                              store              2.0   1.500000   0.707107
# Buenos Aires Costa Atlántica PH                 6.0   3.000000   1.549193
#                              apartment        155.0   5.200000   4.484316
#                              house           2685.0   0.000000   0.000000
#                              store              1.0   1.000000        NaN
# Buenos Aires Interior        PH                 2.0   3.000000   2.828427
#                              apartment         21.0   3.619048   2.438774
#                              house           1325.0   0.000000   0.000000
#                              store              1.0   2.000000        NaN
# Capital Federal              PH               155.0   2.251613   2.211521
#                              apartment       2773.0   4.955283   4.337346
#                              house           2087.0   0.000000   0.000000
#                              store              8.0   9.375000  10.979689
# Córdoba                      PH               268.0   3.910448   2.959053
#                              apartment        344.0   2.587209   3.844417
#                              house           4521.0   0.000000   0.000000
#                              store              9.0   1.333333   0.500000
# Santa Fe                     PH                11.0   2.636364   1.911687
#                              apartment        470.0   4.678723   4.356816
#                              house           1924.0   0.000000   0.000000
#                              store              1.0  10.000000        NaN
#
#                                                                             \
#                                              min    25%   50%    75%   max
# state_name                   property_type
# Bs.As. G.B.A. Zona Norte     PH              1.0   1.00   1.0   2.00   5.0
#                              apartment       1.0   1.00   3.0   5.00  50.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store           1.0   1.00   1.0   1.00   2.0
# Bs.As. G.B.A. Zona Oeste     PH              1.0   1.00   2.0   4.00   9.0
#                              apartment       1.0   2.00   3.0   5.00  24.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store           1.0   1.00   1.0   1.25   2.0
# Bs.As. G.B.A. Zona Sur       PH              1.0   1.00   1.5   2.25  10.0
#                              apartment       1.0   2.00   4.0   7.00  20.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store           1.0   1.25   1.5   1.75   2.0
# Buenos Aires Costa Atlántica PH              2.0   2.00   2.5   3.00   6.0
#                              apartment       1.0   2.00   4.0   7.00  22.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store           1.0   1.00   1.0   1.00   1.0
# Buenos Aires Interior        PH              1.0   2.00   3.0   4.00   5.0
#                              apartment       1.0   2.00   3.0   5.00   8.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store           2.0   2.00   2.0   2.00   2.0
# Capital Federal              PH              1.0   1.00   1.0   3.00  16.0
#                              apartment       1.0   2.00   4.0   7.00  43.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store           1.0   2.00   3.0  15.25  31.0
# Córdoba                      PH              1.0   2.00   3.0   5.25  17.0
#                              apartment       1.0   1.00   1.0   2.00  49.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store           1.0   1.00   1.0   2.00   2.0
# Santa Fe                     PH              1.0   1.00   2.0   4.00   6.0
#                              apartment       1.0   2.00   3.0   7.00  34.0
#                              house           0.0   0.00   0.0   0.00   0.0
#                              store          10.0  10.00  10.0  10.00  10.0
#
#                                            expenses                 ...  \
#                                               count           mean  ...
# state_name                   property_type                          ...
# Bs.As. G.B.A. Zona Norte     PH                43.0     613.976744  ...
#                              apartment       1620.0    3021.644444  ...
#                              house           1344.0    5869.713542  ...
#                              store             74.0    1564.108108  ...
# Bs.As. G.B.A. Zona Oeste     PH                32.0     266.062500  ...
#                              apartment        484.0    2818.095041  ...
#                              house            100.0    3641.730000  ...
#                              store             17.0    1190.823529  ...
# Bs.As. G.B.A. Zona Sur       PH                43.0     462.488372  ...
#                              apartment       1150.0    1503.664348  ...
#                              house            542.0    4589.916974  ...
#                              store             42.0    1203.214286  ...
# Buenos Aires Costa Atlántica PH                 7.0     718.571429  ...
#                              apartment        413.0    2042.121065  ...
#                              house             13.0    3284.692308  ...
#                              store              7.0    2201.571429  ...
# Buenos Aires Interior        PH                 3.0     620.000000  ...
#                              apartment         52.0     891.923077  ...
#                              house             30.0    4508.266667  ...
#                              store              0.0            NaN  ...
# Capital Federal              PH               182.0     962.730769  ...
#                              apartment       6196.0    6634.878631  ...
#                              house             12.0    2675.916667  ...
#                              store            202.0    2896.549505  ...
# Córdoba                      PH                21.0    1221.761905  ...
#                              apartment        806.0    3004.114144  ...
#                              house            140.0    9401.821429  ...
#                              store             39.0    1704.923077  ...
# Santa Fe                     PH                 6.0     520.000000  ...
#                              apartment        287.0    1429.937282  ...
#                              house             14.0  107839.428571  ...
#                              store              9.0     812.222222  ...
#
#                                            surface_covered_in_m2            \
#                                                              75%       max
# state_name                   property_type
# Bs.As. G.B.A. Zona Norte     PH                           105.00     900.0
#                              apartment                     81.00   10145.0
#                              house                        296.00   38240.0
#                              store                        504.50   35000.0
# Bs.As. G.B.A. Zona Oeste     PH                            95.00    5889.0
#                              apartment                     60.00    5165.0
#                              house                        204.00   20383.0
#                              store                        333.00   25186.0
# Bs.As. G.B.A. Zona Sur       PH                           100.00    1200.0
#                              apartment                     75.00    8225.0
#                              house                        240.00   18153.0
#                              store                        320.00   30000.0
# Buenos Aires Costa Atlántica PH                            95.00    6610.0
#                              apartment                     75.00   49000.0
#                              house                        240.00    2250.0
#                              store                        257.75   14000.0
# Buenos Aires Interior        PH                           100.00     195.0
#                              apartment                     85.00    5335.0
#                              house                        218.00   27853.0
#                              store                        326.00    1063.0
# Capital Federal              PH                           115.00    1183.0
#                              apartment                     79.00  187000.0
#                              house                        320.00    8175.0
#                              store                        231.00   10958.0
# Córdoba                      PH                            95.75     380.0
#                              apartment                     70.00    7500.0
#                              house                        260.00   12731.0
#                              store                        327.00   25000.0
# Santa Fe                     PH                            84.25     200.0
#                              apartment                     70.00    6674.0
#                              house                        193.00   11111.0
#                              store                        158.00    3200.0
#
#                                            geonames_id                \
#                                                  count          mean
# state_name                   property_type
# Bs.As. G.B.A. Zona Norte     PH                  736.0  3.439827e+06
#                              apartment          5670.0  3.430987e+06
#                              house              8567.0  3.433279e+06
#                              store               436.0  3.440684e+06
# Bs.As. G.B.A. Zona Oeste     PH                  717.0  3.459767e+06
#                              apartment          3279.0  3.462683e+06
#                              house              3727.0  3.444318e+06
#                              store               218.0  3.450937e+06
# Bs.As. G.B.A. Zona Sur       PH                  529.0  3.432541e+06
#                              apartment          3869.0  3.432994e+06
#                              house              4711.0  3.434999e+06
#                              store               407.0  3.433582e+06
# Buenos Aires Costa Atlántica PH                  536.0  3.452014e+06
#                              apartment          5878.0  3.450465e+06
#                              house              2268.0  3.469434e+06
#                              store               255.0  3.451341e+06
# Buenos Aires Interior        PH                   35.0  3.602832e+06
#                              apartment           833.0  3.711169e+06
#                              house              1217.0  3.557171e+06
#                              store                69.0  3.592632e+06
# Capital Federal              PH                 1766.0  3.529494e+06
#                              apartment         25950.0  3.530139e+06
#                              house              2021.0  3.469355e+06
#                              store              1293.0  3.578327e+06
# Córdoba                      PH                  401.0  3.857698e+06
#                              apartment          6679.0  3.857848e+06
#                              house              4474.0  3.852732e+06
#                              store               464.0  3.856327e+06
# Santa Fe                     PH                   76.0  3.839124e+06
#                              apartment          7967.0  3.838518e+06
#                              house              1910.0  3.836193e+06
#                              store               203.0  3.837897e+06
#
#                                                                       \
#                                                       std        min
# state_name                   property_type
# Bs.As. G.B.A. Zona Norte     PH              58671.914840  3427354.0
#                              apartment       14607.447114  3427354.0
#                              house           29340.298627  3427208.0
#                              store           60942.767817  3427354.0
# Bs.As. G.B.A. Zona Oeste     PH             107944.273049  3427367.0
#                              apartment      113113.261435  3427367.0
#                              house           72951.896057  3427367.0
#                              store           90446.577198  3427367.0
# Bs.As. G.B.A. Zona Sur       PH              17658.417806  3427326.0
#                              apartment       13237.991104  3427326.0
#                              house           31696.525712  3427326.0
#                              store           20043.684752  3427326.0
# Buenos Aires Costa Atlántica PH             263325.814395  3427431.0
#                              apartment      150360.676876  3427431.0
#                              house          332677.617774  3427431.0
#                              store          225561.690422  3427431.0
# Buenos Aires Interior        PH             212478.196523  3427832.0
#                              apartment      198589.908771  3427832.0
#                              house          193689.899416  3427212.0
#                              store          208119.067380  3427511.0
# Capital Federal              PH             556658.475395  3427366.0
#                              apartment      555737.593268  3427366.0
#                              house          345993.449956  3427366.0
#                              store          675300.520405  3427366.0
# Córdoba                      PH               7360.672995  3832729.0
#                              apartment        7276.569701  3832631.0
#                              house           66486.470392  3832398.0
#                              store            8964.362660  3832718.0
# Santa Fe                     PH               3497.582913  3836277.0
#                              apartment       10580.215321  3429594.0
#                              house          117594.088319  3428973.0
#                              store           29302.190341  3429594.0
#
#                                                                              \
#                                                   25%        50%        75%
# state_name                   property_type
# Bs.As. G.B.A. Zona Norte     PH             3428983.0  3430511.0  3433908.0
#                              apartment      3428983.0  3430310.0  3430813.0
#                              house          3427753.0  3430310.0  3434130.0
#                              store          3428983.0  3430813.0  3433908.0
# Bs.As. G.B.A. Zona Oeste     PH             3429244.0  3430544.0  3433522.0
#                              apartment      3429617.0  3430544.0  3433359.0
#                              house          3429617.0  3430696.0  3433473.0
#                              store          3429617.0  3430550.0  3433497.5
# Bs.As. G.B.A. Zona Sur       PH             3429636.0  3432039.0  3433321.0
#                              apartment      3431270.0  3432039.0  3435719.0
#                              house          3429651.0  3432039.0  3435719.0
#                              store          3431270.0  3432039.0  3435894.0
# Buenos Aires Costa Atlántica PH             3430863.0  3430863.0  3430863.0
#                              apartment      3430863.0  3430863.0  3430863.0
#                              house          3429971.0  3430863.0  3430863.0
#                              store          3430863.0  3430863.0  3430863.0
# Buenos Aires Interior        PH             3430982.0  3435907.0  3860163.0
#                              apartment      3435907.0  3838609.0  3865084.0
#                              house          3430982.0  3433800.0  3833874.0
#                              store          3430982.0  3435689.0  3860163.0
# Capital Federal              PH             3429422.0  3430787.0  3433955.0
#                              apartment      3429760.0  3433775.0  3436003.0
#                              house          3430114.0  3433910.0  3433955.0
#                              store          3429595.0  3430787.0  3435548.0
# Córdoba                      PH             3860259.0  3860259.0  3860259.0
#                              apartment      3860255.0  3860259.0  3860259.0
#                              house          3839996.0  3860255.0  3860259.0
#                              store          3860255.0  3860259.0  3860259.0
# Santa Fe                     PH             3838574.0  3838574.0  3838574.0
#                              apartment      3838574.0  3838574.0  3838574.0
#                              house          3837090.0  3838574.0  3838638.0
#                              store          3838574.0  3838574.0  3838574.0
#
#
#                                                   max
# state_name                   property_type
# Bs.As. G.B.A. Zona Norte     PH             3832698.0
#                              apartment      3850312.0
#                              house          3856531.0
#                              store          3856531.0
# Bs.As. G.B.A. Zona Oeste     PH             3862356.0
#                              apartment      3862356.0
#                              house          3862356.0
#                              store          3862356.0
# Bs.As. G.B.A. Zona Sur       PH             3832749.0
#                              apartment      3845073.0
#                              house          3845073.0
#                              store          3832749.0
# Buenos Aires Costa Atlántica PH             6942539.0
#                              apartment      6942539.0
#                              house          6942539.0
#                              store          6942538.0
# Buenos Aires Interior        PH             3865084.0
#                              apartment      3865084.0
#                              house          3866926.0
#                              store          3865084.0
# Capital Federal              PH             6693230.0
#                              apartment      6693230.0
#                              house          6693230.0
#                              store          6693230.0
# Córdoba                      PH             3860259.0
#                              apartment      3866959.0
#                              house          6948895.0
#                              store          3866959.0
# Santa Fe                     PH             3856022.0
#                              apartment      3865485.0
#                              house          6942842.0
#                              store          3862738.0
#
# [32 rows x 96 columns]

# %%
min_surface_covered_in_m2 = data["surface_covered_in_m2"].min()
print("min_surface_covered_in_m2", min_surface_covered_in_m2)

max_surface_covered_in_m2 = data["surface_covered_in_m2"].max()
print("max_surface_covered_in_m2", max_surface_covered_in_m2)

mean_surface_covered_in_m2 = data["surface_covered_in_m2"].mean()
print("mean_surface_covered_in_m2", mean_surface_covered_in_m2)
# Out:
# min_surface_covered_in_m2 0.0
# max_surface_covered_in_m2 187000.0
# mean_surface_covered_in_m2 133.05018112186985

# %%
#Estoy queriendo ver cuál es el dato que tiene este valor de superficie cubierta en m2 pero no estoy pudiendo dar en cómo hacerlo.
data.sort_values("surface_covered_in_m2", ascending=False)
# Out:
#        property_type       place_name  \
# 76012      apartment     Barrio Norte
# 35151      apartment    Mar del Plata
# 39221          house            Delta
# 68304          store      Tortuguitas
# 106376         store  Lomas de Zamora
# ...              ...              ...
# 121203     apartment          Córdoba
# 121204     apartment          Córdoba
# 121205     apartment          Córdoba
# 121206     apartment          Córdoba
# 121209     apartment         Belgrano
#
#                                   place_with_parent_names country_name  \
# 76012            |Argentina|Capital Federal|Barrio Norte|    Argentina
# 35151   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 39221    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Delta|    Argentina
# 68304   |Argentina|Bs.As. G.B.A. Zona Norte|Malvinas A...    Argentina
# 106376  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...    Argentina
# ...                                                   ...          ...
# 121203                                |Argentina|Córdoba|    Argentina
# 121204                                |Argentina|Córdoba|    Argentina
# 121205                                |Argentina|Córdoba|    Argentina
# 121206                                |Argentina|Córdoba|    Argentina
# 121209               |Argentina|Capital Federal|Belgrano|    Argentina
#
#                           state_name  geonames_id        lat        lon  \
# 76012                Capital Federal    3436109.0 -34.594573 -58.409166
# 35151   Buenos Aires Costa Atlántica    3430863.0 -37.989809 -57.547773
# 39221       Bs.As. G.B.A. Zona Norte          NaN        NaN        NaN
# 68304       Bs.As. G.B.A. Zona Norte          NaN        NaN        NaN
# 106376        Bs.As. G.B.A. Zona Sur    3431270.0 -34.781917 -58.425045
# ...                              ...          ...        ...        ...
# 121203                       Córdoba    3860255.0        NaN        NaN
# 121204                       Córdoba    3860255.0        NaN        NaN
# 121205                       Córdoba    3860255.0        NaN        NaN
# 121206                       Córdoba    3860255.0        NaN        NaN
# 121209               Capital Federal    3436077.0 -34.563685 -58.442683
#
#             price currency  ...  surface_covered_in_m2  price_usd_per_m2  \
# 76012    600000.0      USD  ...               187000.0               NaN
# 35151     74000.0      USD  ...                49000.0       1423.076923
# 39221    620000.0      USD  ...                38240.0        516.666667
# 68304         NaN      NaN  ...                35000.0               NaN
# 106376  6000000.0      USD  ...                30000.0         64.516129
# ...           ...      ...  ...                    ...               ...
# 121203  1502000.0      ARS  ...                    NaN       1684.753600
# 121204  1502000.0      ARS  ...                    NaN       1684.753600
# 121205  1507000.0      ARS  ...                    NaN       1690.362000
# 121206  1507000.0      ARS  ...                    NaN       1690.362000
# 121209   410000.0      USD  ...                    NaN       2611.464968
#
#         price_per_m2  floor  rooms  expenses  \
# 76012       3.208556    NaN    NaN   11000.0
# 35151       1.510204    NaN    2.0       NaN
# 39221      16.213389    NaN    NaN       NaN
# 68304            NaN    NaN    NaN       NaN
# 106376    200.000000    NaN    NaN       NaN
# ...              ...    ...    ...       ...
# 121203           NaN    NaN    NaN       NaN
# 121204           NaN    NaN    NaN       NaN
# 121205           NaN    NaN    NaN       NaN
# 121206           NaN    NaN    NaN       NaN
# 121209           NaN    NaN    NaN    6300.0
#
#                                             properati_url  \
# 76012   http://www.properati.com.ar/1ar12_venta_depart...
# 35151   http://www.properati.com.ar/18dqk_venta_depart...
# 39221   http://www.properati.com.ar/18n5v_venta_casa_d...
# 68304   http://www.properati.com.ar/1agmu_venta_local_...
# 106376  http://www.properati.com.ar/1bw9v_venta_local_...
# ...                                                   ...
# 121203  http://www.properati.com.ar/1cj72_venta_depart...
# 121204  http://www.properati.com.ar/1cj73_venta_depart...
# 121205  http://www.properati.com.ar/1cj74_venta_depart...
# 121206  http://www.properati.com.ar/1cj75_venta_depart...
# 121209  http://www.properati.com.ar/1cj7c_venta_depart...
#
#                                               description  \
# 76012   Barrio Norte EXCELENTE Semipiso al Frente Balc...
# 35151   OPORTUNIDAD!!! VENTA DOS AMBIENTES FRENTE A PL...
# 39221   Terreno de 20mts frente x 60mts fondo, Total 1...
# 68304   Plaza Logística Tortugas CÓDIGO 0703 T35.000 m...
# 106376  CODIGO: 2484-FB0007 ubicado en: Garibaldi al 2...
# ...                                                   ...
# 121203  UBICACIÓNEstratégicamente ubicado en calle Obi...
# 121204  UBICACIÓNEstratégicamente ubicado en calle Obi...
# 121205  UBICACIÓNEstratégicamente ubicado en calle Obi...
# 121206  UBICACIÓNEstratégicamente ubicado en calle Obi...
# 121209  Edificio en esquina de muy buena categoría de ...
#
#                                                     title  \
# 76012                      Excelente PISO en Barrio Norte
# 35151                      oportunidad frente al  mar!!!!
# 39221   Casa 1200m² con 2 Plantas, Tigre, Delta, por U...
# 68304                       Nave Industrial - Tortuguitas
# 106376  LAVALLOL. Predio Industrial de 93.000 m2 y 30....
# ...                                                   ...
# 121203                       Departamento - Nueva Cordoba
# 121204                       Departamento - Nueva Cordoba
# 121205                       Departamento - Nueva Cordoba
# 121206                       Departamento - Nueva Cordoba
# 121209  Av .Luis Maria Campos 1400- Belgrano-Capital F...
#
#                                           image_thumbnail
# 76012   https://thumbs4.properati.com/0/Z9TPL-aDoGIWcI...
# 35151   https://thumbs4.properati.com/9/eYTtojBrMLeOIU...
# 39221   https://thumbs4.properati.com/3/YHyoqoUw4VXZBy...
# 68304   https://thumbs4.properati.com/2/bS5f2FMQrZr9Rz...
# 106376  https://thumbs4.properati.com/8/Ov_ck7GARrYKi0...
# ...                                                   ...
# 121203                                                NaN
# 121204                                                NaN
# 121205                                                NaN
# 121206                                                NaN
# 121209  https://thumbs4.properati.com/0/zeLNBuyylOJL7z...
#
# [121220 rows x 23 columns]

# %%
data.pivot_table("price_usd_per_m2", index="state_name", columns="property_type", aggfunc=["mean", "max", "min"])
# Out:
#                                      mean                            \
# property_type                          PH    apartment        house
# state_name
# Bs.As. G.B.A. Zona Norte      1451.712566  2539.871735  1339.764409
# Bs.As. G.B.A. Zona Oeste      1224.018825  1720.754481  1081.629587
# Bs.As. G.B.A. Zona Sur        1114.012013  1889.978782  1164.503788
# Buenos Aires Costa Atlántica  1156.454370  1958.838430   749.149782
# Buenos Aires Interior         1019.888682  1633.999387   643.236465
# Capital Federal               1695.517729  3324.464870  1546.701574
# Catamarca                             NaN          NaN   556.045469
# Chaco                                 NaN  1424.743536   701.166824
# Chubut                                NaN  2002.694843  1739.270312
# Corrientes                    1478.503224  1933.717616  1157.180835
# Córdoba                       1544.048178  1426.524689   713.335035
# Entre Ríos                            NaN  1383.244968  1119.484937
# Formosa                               NaN  1509.648462          NaN
# Jujuy                                 NaN  1682.510200   261.933196
# La Pampa                              NaN  1305.023938   858.320502
# La Rioja                              NaN          NaN   243.029233
# Mendoza                       1113.716814  1966.691498  1347.909268
# Misiones                      1154.663824  1287.519642   469.735704
# Neuquén                       2313.924378  1894.646765  1138.848461
# Río Negro                     1284.275970  2627.957903  1564.846278
# Salta                                 NaN  2987.691166  2128.169804
# San Juan                              NaN  3191.489362   104.999120
# San Luis                              NaN  1724.424645  1597.285854
# Santa Cruz                            NaN          NaN   725.064327
# Santa Fe                      1207.188748  2391.993013   990.905762
# Santiago Del Estero                   NaN   513.308136   148.000000
# Tierra Del Fuego                      NaN  1820.550732   769.871670
# Tucumán                       1329.819072  1495.412049  1047.004923
#
#                                                     max                 \
# property_type                       store            PH      apartment
# state_name
# Bs.As. G.B.A. Zona Norte      1862.009755  11333.333333   48296.222222
# Bs.As. G.B.A. Zona Oeste      1556.947316  16000.000000   24500.000000
# Bs.As. G.B.A. Zona Sur        1541.024184   2800.000000   23140.764706
# Buenos Aires Costa Atlántica  1401.045662   5957.446809   21897.058824
# Buenos Aires Interior          987.670901   1867.647059    3657.142857
# Capital Federal               2899.667204  25000.000000  206333.333333
# Catamarca                             NaN           NaN            NaN
# Chaco                         1509.551047           NaN    2386.363636
# Chubut                        1323.758082           NaN    3306.666667
# Corrientes                    1346.188700   3342.391304    2958.333333
# Córdoba                       1458.775597  30000.000000   14960.000000
# Entre Ríos                    1602.058545           NaN    2811.525424
# Formosa                               NaN           NaN    1514.259219
# Jujuy                                 NaN           NaN    1682.510200
# La Pampa                       616.920440           NaN    1402.091875
# La Rioja                              NaN           NaN            NaN
# Mendoza                       1361.578717   1327.433628   31578.947368
# Misiones                        71.604472   1154.663824    3115.384615
# Neuquén                       1181.086043   2805.519048    9500.000000
# Río Negro                     1504.330703   1707.317073    4342.906832
# Salta                          179.467760           NaN   23750.000000
# San Juan                              NaN           NaN    3191.489362
# San Luis                      1369.953236           NaN   11333.333333
# Santa Cruz                     420.627542           NaN            NaN
# Santa Fe                      3002.901146   1724.573000   44425.675676
# Santiago Del Estero                   NaN           NaN     513.308136
# Tierra Del Fuego              1100.747107           NaN    3371.428571
# Tucumán                        600.299163   1329.819072   21666.666667
#
#                                                                   min  \
# property_type                        house         store           PH
# state_name
# Bs.As. G.B.A. Zona Norte      38000.000000  20833.333333    49.485588
# Bs.As. G.B.A. Zona Oeste      80000.000000  11818.181818    77.893944
# Bs.As. G.B.A. Zona Sur         9411.764706  13000.000000    50.475300
# Buenos Aires Costa Atlántica   5698.005128   4740.259740    55.000000
# Buenos Aires Interior          4166.666667   2333.333333    45.824847
# Capital Federal               23064.516129  22000.000000   120.964706
# Catamarca                      1666.666667           NaN          NaN
# Chaco                          1357.142857   2134.146341          NaN
# Chubut                        14540.550661   2600.000000          NaN
# Corrientes                     3500.000000   2380.952381   787.037037
# Córdoba                       16666.666667   5521.472393    36.601307
# Entre Ríos                    24038.461538   3703.703704          NaN
# Formosa                                NaN           NaN          NaN
# Jujuy                           295.216741           NaN          NaN
# La Pampa                       1243.791210    616.920440          NaN
# La Rioja                        243.029233           NaN          NaN
# Mendoza                       22666.666667   2750.000000   900.000000
# Misiones                       4206.275000    133.333333  1154.663824
# Neuquén                       17073.170732   3000.000000    13.566680
# Río Negro                     17857.142857   4615.384615   463.157895
# Salta                         18666.666667    179.467760          NaN
# San Juan                        104.999120           NaN          NaN
# San Luis                      33333.333333   2631.578947          NaN
# Santa Cruz                     2166.666667    420.627542          NaN
# Santa Fe                      36549.707237  57382.080000   218.103167
# Santiago Del Estero             224.000000           NaN          NaN
# Tierra Del Fuego               1402.091900   1200.000000          NaN
# Tucumán                       14705.882353   1686.516238  1329.819072
#
#
# property_type                   apartment       house        store
# state_name
# Bs.As. G.B.A. Zona Norte        29.906933    4.166667   158.730159
# Bs.As. G.B.A. Zona Oeste        20.898642    7.000000    28.041833
# Bs.As. G.B.A. Zona Sur          91.135875   19.314341    22.222222
# Buenos Aires Costa Atlántica     1.000000    3.000000    82.540833
# Buenos Aires Interior           15.160342    2.072029   133.928571
# Capital Federal                 31.369688  190.000000    13.797467
# Catamarca                             NaN  145.454545          NaN
# Chaco                          539.265962  163.033942   884.955752
# Chubut                         599.964884   13.500000   411.764706
# Corrientes                    1442.307692   83.682008   373.210634
# Córdoba                          1.184571   12.254902    31.406853
# Entre Ríos                     434.648375    5.608367   690.000000
# Formosa                       1490.540000         NaN          NaN
# Jujuy                         1682.510200  210.313787          NaN
# La Pampa                      1207.956000  392.585700   616.920440
# La Rioja                              NaN  243.029233          NaN
# Mendoza                        237.642627   16.467066    52.941176
# Misiones                       397.259333   39.689985     9.875610
# Neuquén                        122.641509   72.115385   274.038462
# Río Negro                      466.666667   82.039262   466.666667
# Salta                          583.328471   51.746877   179.467760
# San Juan                      3191.489362  104.999120          NaN
# San Luis                       162.500000   11.216735   312.500000
# Santa Cruz                            NaN  315.969583   420.627542
# Santa Fe                         0.600000    9.388501   416.666667
# Santiago Del Estero            513.308136   72.000000          NaN
# Tierra Del Fuego               417.804564  362.207042  1001.494214
# Tucumán                        210.176061   62.653778    30.399476

# %%
data.pivot_table("price_usd_per_m2", ["state_name", "property_type"], columns="surface_covered_in_m2")
# Out:
# surface_covered_in_m2                   0.0          1.0      2.0      \
# state_name               property_type
# Bs.As. G.B.A. Zona Norte PH                 NaN          NaN      NaN
#                          apartment          NaN          NaN   2380.0
#                          house              NaN  3021.995642      NaN
#                          store              NaN          NaN      NaN
# Bs.As. G.B.A. Zona Oeste PH                 NaN          NaN      NaN
# ...                                         ...          ...      ...
# Tierra Del Fuego         store              NaN          NaN      NaN
# Tucumán                  PH                 NaN          NaN      NaN
#                          apartment          NaN          NaN      NaN
#                          house              NaN          NaN      NaN
#                          store              NaN          NaN      NaN
#
# surface_covered_in_m2                   3.0      4.0      5.0      \
# state_name               property_type
# Bs.As. G.B.A. Zona Norte PH                 NaN      NaN      NaN
#                          apartment          NaN      NaN      NaN
#                          house              NaN      NaN      NaN
#                          store              NaN      NaN      NaN
# Bs.As. G.B.A. Zona Oeste PH                 NaN      NaN      NaN
# ...                                         ...      ...      ...
# Tierra Del Fuego         store              NaN      NaN      NaN
# Tucumán                  PH                 NaN      NaN      NaN
#                          apartment          NaN      NaN      NaN
#                          house              NaN      NaN      NaN
#                          store              NaN      NaN      NaN
#
# surface_covered_in_m2                       6.0          7.0      8.0      \
# state_name               property_type
# Bs.As. G.B.A. Zona Norte PH                     NaN          NaN      NaN
#                          apartment      2363.636364  2181.818182      NaN
#                          house                  NaN          NaN      NaN
#                          store                  NaN          NaN      NaN
# Bs.As. G.B.A. Zona Oeste PH                     NaN          NaN      NaN
# ...                                             ...          ...      ...
# Tierra Del Fuego         store                  NaN          NaN      NaN
# Tucumán                  PH                     NaN          NaN      NaN
#                          apartment              NaN          NaN      NaN
#                          house                  NaN          NaN      NaN
#                          store                  NaN          NaN      NaN
#
# surface_covered_in_m2                       9.0      ...  14000.0  18615.0  \
# state_name               property_type               ...
# Bs.As. G.B.A. Zona Norte PH                     NaN  ...      NaN      NaN
#                          apartment      2122.666429  ...      NaN      NaN
#                          house                  NaN  ...      NaN      NaN
#                          store                  NaN  ...      NaN      NaN
# Bs.As. G.B.A. Zona Oeste PH                     NaN  ...      NaN      NaN
# ...                                             ...  ...      ...      ...
# Tierra Del Fuego         store                  NaN  ...      NaN      NaN
# Tucumán                  PH                     NaN  ...      NaN      NaN
#                          apartment              NaN  ...      NaN      NaN
#                          house                  NaN  ...      NaN      NaN
#                          store                  NaN  ...      NaN      NaN
#
# surface_covered_in_m2                      18635.0  19609.0     23871.0  \
# state_name               property_type
# Bs.As. G.B.A. Zona Norte PH                    NaN      NaN         NaN
#                          apartment             NaN      NaN         NaN
#                          house          435.294118      NaN  648.148148
#                          store                 NaN      NaN         NaN
# Bs.As. G.B.A. Zona Oeste PH                    NaN      NaN         NaN
# ...                                            ...      ...         ...
# Tierra Del Fuego         store                 NaN      NaN         NaN
# Tucumán                  PH                    NaN      NaN         NaN
#                          apartment             NaN      NaN         NaN
#                          house                 NaN      NaN         NaN
#                          store                 NaN      NaN         NaN
#
# surface_covered_in_m2                   25000.0  27853.0  30000.0     38240.0  \
# state_name               property_type
# Bs.As. G.B.A. Zona Norte PH                 NaN      NaN      NaN         NaN
#                          apartment          NaN      NaN      NaN         NaN
#                          house              NaN      NaN      NaN  516.666667
#                          store              NaN      NaN      NaN         NaN
# Bs.As. G.B.A. Zona Oeste PH                 NaN      NaN      NaN         NaN
# ...                                         ...      ...      ...         ...
# Tierra Del Fuego         store              NaN      NaN      NaN         NaN
# Tucumán                  PH                 NaN      NaN      NaN         NaN
#                          apartment          NaN      NaN      NaN         NaN
#                          house              NaN      NaN      NaN         NaN
#                          store              NaN      NaN      NaN         NaN
#
# surface_covered_in_m2                   49000.0
# state_name               property_type
# Bs.As. G.B.A. Zona Norte PH                 NaN
#                          apartment          NaN
#                          house              NaN
#                          store              NaN
# Bs.As. G.B.A. Zona Oeste PH                 NaN
# ...                                         ...
# Tierra Del Fuego         store              NaN
# Tucumán                  PH                 NaN
#                          apartment          NaN
#                          house              NaN
#                          store              NaN
#
# [86 rows x 811 columns]

# %%
data.duplicated().sum()
# Out:
# 0
